# %%
from cmath import nan
from PIL import Image
import numpy as np
from numpy import asarray
import matplotlib.pyplot as plt
import os, glob
from PIL import Image
import cv2
import pandas as pd

# %%
"""
image registration and cropping functions
"""
def align_to_standard(img_dir, src_dir='src.jpeg'):
    src_color = cv2.imread(src_dir)
    sbj_color = cv2.imread(img_dir)

    src = cv2.cvtColor(src_color, cv2.COLOR_BGR2GRAY)
    sbj = cv2.cvtColor(sbj_color, cv2.COLOR_BGR2GRAY)
    
    orb_detector = cv2.ORB_create(2000)
    src_keypoints, src_descriptors = orb_detector.detectAndCompute(src, None)
    sbj_keypoints, sbj_descriptors = orb_detector.detectAndCompute(sbj,None)

    matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)
    matches = list(matcher.match(sbj_descriptors, src_descriptors))
    
    matches.sort(key = lambda x: x.distance)
    matches = matches[:int(len(matches)*0.9)]
    # records matched keypoints' coordinates
    no_of_matches = len(matches)
    p1 = np.zeros((no_of_matches, 2))
    p2 = np.zeros((no_of_matches, 2))

    for i in range(no_of_matches):
        p1[i, :] = sbj_keypoints[matches[i].queryIdx].pt
        p2[i, :] = src_keypoints[matches[i].trainIdx].pt
    
    homography, mask = cv2.findHomography(p1, p2, cv2.RANSAC)
    transformed_img = cv2.warpPerspective(sbj_color,
                        homography, (src.shape[1], src.shape[0]))
    return transformed_img

def crop_rotate_dir(img, og_file_dir, output_dir, angle = -1.5, left = 135, upper =85, right = 600, lower = 390):
    filename = og_file_dir.split('/')[-1]
    im = Image.fromarray(img)
    rotated = im.rotate(angle, expand = 1)
    im_final = rotated.crop((left, upper, right, lower))            
    im_final.save(output_dir+'/'+filename)

# %%
"""
input: filename of plate
output: pd df of the ground truth for that plate
"""
from typing import Tuple

all_labels = pd.read_csv('updated_ground_truth.csv')

def get_ground_truth(filename: str):
    id = filename.split('_')[-1].split('.')[0]
    this_labels = all_labels.loc[all_labels["destination_plate_bcode"]==int(id),['destination_well']].to_numpy()
    return this_labels
    
"""
return ngs data delivery success for all wells in this plate; type = pandas df
"""
all_labels_w_ngs = pd.read_csv('updated_ground_truth_ngs.csv')
def get_ground_truth_w_ngs(filename: str):
    id = filename.split('_')[-1].split('.')[0]
    successes = all_labels_w_ngs.loc[all_labels_w_ngs["destination_plate_bcode"]==int(id), ['ngs_data_delivery_success', 'destination_well']]
    return successes

"""
gaussian_kernel_size: greater = blurring in larger neighborhood
gaussian_sigma: greater sigma = more blurring
adp_th_block_size needs to be odd: greater = looking at local intensities in a larger neighborhood
adp_th_const is a constant that is subtracted from the weighted mean; greater = effectively more noise reduction
"""
def load_and_preprocess_img(filename: str, gaussian_kernel_size: Tuple = (3,3), adapt=cv2.ADAPTIVE_THRESH_GAUSSIAN_C, thresh=cv2.THRESH_BINARY_INV, gaussian_sigma: float = 1.0, adp_th_block_size: int = 5, adp_th_const: int = 4):
    img = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)
    img_blurred = cv2.GaussianBlur(img, gaussian_kernel_size, gaussian_sigma)
    img_th = cv2.adaptiveThreshold(img_blurred, 255, adapt, thresh, adp_th_block_size, adp_th_const)
    return img_th

"""
exclude wells with black background
"""
def exclude_wells(col_idx, row_idx):
    # M3, M4, A12, A13, P12, P13, C21
    if ((col_idx == 2 or col_idx == 3) and row_idx == 12) or ((row_idx ==0 or row_idx == 15) and (col_idx==11 or col_idx ==12)) or (row_idx == 2 and col_idx==20):
        return True
    return False
"""
input: img or preprocessed img
output: conceptually a matrix of 16 x 24, each entry is the isolated well image
"""
def isolate_each_well(img_th):
    to_return = []
    y = img_th.shape[0] / 16
    x = img_th.shape[1] / 24
    for row in np.arange(0, img_th.shape[0], y):
        col_out = []
        for col in np.arange(0, img_th.shape[1], x):
            col_out.append(img_th[round(row):round(row+y),round(col):round(col+x)])
        to_return.append(col_out)
    return np.array(to_return, dtype=object)

"""
If one and only one particle is detected, report 1
If no particle detected, report 0
else: report -1 to indicate ambiguity
"""
def particle_detection_prediction(well_img):
    nb_components, arr = cv2.connectedComponents(well_img, connectivity=8)
    if nb_components - 1 == 1:
        pred = 1
    elif nb_components - 1 == 0:
        pred = 0
    else:
        pred = -1
    return pred

# %%
"""
Uses particle detection to predict whether or not bead is present.
Returns accuracy and a list of unsure well locations for each img (if particle_detection_prediction returns -1)
    which means that more than one particle is detected in the well
"""
from numpy import isnan
from collections import defaultdict

def melodys_pipeline(thresh=cv2.THRESH_BINARY, adapt=cv2.ADAPTIVE_THRESH_GAUSSIAN_C, block=5, c=4, k=9, registration=False, input_dir = '../second_batch_img/', cropped_output_dir = '../cropped_second_batch_img/'):
    # save aligned and cropped imgs to disk to avoid taking up too much memory
    # if registration:
    #     cropped_output_dir = 'cropped2/'
    # for filename in glob.glob(input_dir+'/*.jpg'):
    #     # print(filename)
    #     if registration:
    #         img = align_to_standard(filename)
    #     else:
    #         img = cv2.imread(filename)
    #     crop_rotate_dir(img, filename, output_dir=cropped_output_dir,left = 135, upper =85, right = 600, lower = 390)

    accuracy_list = []
    with_label = []
    no_label = []
    y_true, y_pred = [], []
    failed_bc_dispense = 0
    failed_not_dc_dispense = 0
    ngs_success_counter = 0
    ngs_failed_counter = 0
    true_false_neg_counter = 0
    ngs_nan = 0
    # wells = defaultdict(lambda:0)
    # totals = defaultdict(lambda:0)
    # specials = defaultdict(lambda:0)
    # unsure_dict = {}
    # read every image file from the input folder
    for filename in glob.glob(cropped_output_dir +'/*.jpg'):
        # print(filename)
        right = 0
        wrong = 0
        unsure = []
        labels = get_ground_truth(filename)
        if len(labels) == 0:
            no_label.append(filename)
            continue
        with_label.append(filename)

        ngs_successes_df = get_ground_truth_w_ngs(filename)
        ngs_successes_np = ngs_successes_df.to_numpy()

        img_th = load_and_preprocess_img(filename=filename, gaussian_kernel_size=(3,3), thresh=thresh, adapt=adapt, adp_th_block_size=block, adp_th_const=c, gaussian_sigma=1.0)
        # print(type(img_th))
        well_imgs = isolate_each_well(img_th)
        for row in range(well_imgs.shape[0]):
            for col in range(well_imgs.shape[1]):
                if exclude_wells(col, row):
                    continue
                
                # crop out a kxk square in the center of the well
                well = np.array(well_imgs[row,col])
                if well.shape[1] == 20:
                    well = well[:, :-1]
                row_diff = (well.shape[0] - k) // 2
                well = well[row_diff:, :]
                well = well[:k, :]
                well = well[:, row_diff:]
                well = well[:, :k]
                
                # pred = particle_detection_prediction(well) # comment this if using only num of val in thresholded img and uncomment the following line
                pred = len(np.unique(well)) - 1 

                #generate well id for df lookup
                well_id = chr(ord('A') + row) + str(col + 1)

                # get ngs success for this well
                # ngs_success = ngs_successes_df.loc[ngs_successes_df['destination_well'] == well_id,['ngs_data_delivery_success']].to_numpy().flatten()
                ngs_success = ngs_successes_np[np.where(ngs_successes_np[:,1] == well_id),0].flatten()
            
                if len(ngs_success) == 0 or ngs_success[0] == nan:
                    ngs_success = nan
                else:
                    ngs_success = ngs_success[0]
                #count ngs success
                if ngs_success == True:
                    ngs_success_counter += 1
                elif ngs_success == False:
                    ngs_failed_counter += 1
                else:
                    ngs_nan += 1

                if pred != -1:
                    y_pred.append(pred)

                    #get truth
                    # totals[well_id] += 1
                    if well_id in labels:
                        truth = 1
                    else:
                        truth = 0
                    # if well_id in ['A11', 'A14'] and truth == 1:
                    #     specials[well_id] += 1
                    # elif well_id in ['P11', 'P14'] and truth == 1:
                    #     specials[well_id] += 1
                    y_true.append(truth)   
                    if pred == truth:
                        # wells[well_id] += 1
                        right += 1

                        if pred == 1 and ngs_success == False: # if definitely have beads but ngs not successful
                            failed_not_dc_dispense += 1

                    else:
                        wrong += 1
                        if pred == 0 and truth == 1: # if false negative, check if ngs delivery failed
                            if ngs_success == False: # if ngs delivery failed
                                # y_true[-1] = 0
                                failed_bc_dispense += 1
                            elif ngs_success == True: # if ngs delivery successful then it must mean that there are beads
                                true_false_neg_counter += 1
                                # plt.figure(true_false_neg_counter)
                                print(filename,f'row: {row}, col: {col}')
                else:
                    unsure.append([row, col])
        accuracy_list.append(right / (right + wrong + len(unsure)))
        # unsure_dict[filename] = len(unsure)
    # print("unsure: ", unsure)
    # return accuracy_list, y_true, y_pred, wells, totals, specials, with_label, no_label, true_false_neg_counter, failed_bc_dispense/ngs_failed_counter, failed_not_dc_dispense/ngs_failed_counter, ngs_success_counter, ngs_failed_counter, ngs_nan #, unsure_dict
    return accuracy_list, y_true, y_pred, with_label, no_label, true_false_neg_counter, failed_bc_dispense/ngs_failed_counter, failed_not_dc_dispense/ngs_failed_counter, ngs_success_counter, ngs_failed_counter, ngs_nan #, unsure_dict
    # return None
    # return None

# %%
accs, _, _, _, _, true_false_neg_counter, failed_bc_dispense, failed_not_dc_dispense, ngs_success_counter, ngs_failed_counter, ngs_nan = melodys_pipeline(cv2.THRESH_BINARY, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 5, 4, k=9, registration=False)
print(np.mean(accs))
plt.hist(accs)
# Out:
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 0
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 2
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 4
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 6
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 8
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 14
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 16
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 18
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 20
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 0, col: 22
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 0
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 2
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 4
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 6
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 8
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 10
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 12
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 14
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 2, col: 16
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 4, col: 0
# ../cropped_second_batch_img/220215_144028_887739.jpg row: 4, col: 4
# ../cropped_second_batch_img/220324_121939_908873.jpg row: 12, col: 23
# ../cropped_second_batch_img/220324_121939_908873.jpg row: 13, col: 1
# ../cropped_second_batch_img/220324_121939_908873.jpg row: 15, col: 6
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 0, col: 17
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 1, col: 0
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 1, col: 22
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 2, col: 10
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 4, col: 14
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 6, col: 23
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 11, col: 0
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 14, col: 2
# ../cropped_second_batch_img/220223_173011_893157.jpg row: 15, col: 19
# ../cropped_second_batch_img/220413_101822_920196.jpg row: 0, col: 15
# ../cropped_second_batch_img/220413_101822_920196.jpg row: 0, col: 20
# ../cropped_second_batch_img/220413_101822_920196.jpg row: 1, col: 22
# ../cropped_second_batch_img/220413_101822_920196.jpg row: 1, col: 23
# ../cropped_second_batch_img/220926_131430_1025332.jpg row: 1, col: 23
# ../cropped_second_batch_img/220510_131556_934454.jpg row: 6, col: 1
# ../cropped_second_batch_img/220913_131611_1016725.jpg row: 1, col: 6
# ../cropped_second_batch_img/220913_131611_1016725.jpg row: 1, col: 20
# ../cropped_second_batch_img/220913_131611_1016725.jpg row: 2, col: 13
# ../cropped_second_batch_img/221004_130811_1031282.jpg row: 1, col: 22
# ../cropped_second_batch_img/221004_130811_1031282.jpg row: 10, col: 1
# ../cropped_second_batch_img/221004_130811_1031282.jpg row: 15, col: 18
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 0, col: 0
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 0, col: 10
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 0, col: 16
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 0, col: 19
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 0, col: 20
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 1, col: 2
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 1, col: 20
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 2, col: 0
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 2, col: 22
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 6, col: 17
# ../cropped_second_batch_img/220425_132629_926220.jpg row: 8, col: 18
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 0, col: 17
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 1, col: 1
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 1, col: 14
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 2, col: 21
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 9, col: 11
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 10, col: 8
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 11, col: 6
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 13, col: 1
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 14, col: 0
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 14, col: 2
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 14, col: 18
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 15, col: 0
# ../cropped_second_batch_img/220427_130311_927662.jpg row: 15, col: 2
# ../cropped_second_batch_img/220106_114156_863264.jpg row: 5, col: 23
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 0, col: 4
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 0, col: 5
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 0, col: 6
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 0, col: 9
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 0, col: 20
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 2, col: 0
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 2, col: 6
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 2, col: 23
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 4, col: 1
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 4, col: 10
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 4, col: 23
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 6, col: 7
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 8, col: 12
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 10, col: 4
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 10, col: 6
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 11, col: 8
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 11, col: 9
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 12, col: 0
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 12, col: 21
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 13, col: 5
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 13, col: 22
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 14, col: 3
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 14, col: 6
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 14, col: 8
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 14, col: 18
# ../cropped_second_batch_img/220802_123234_987062.jpg row: 15, col: 4
# ../cropped_second_batch_img/220908_131915_1014585.jpg row: 0, col: 23
# ../cropped_second_batch_img/220908_131915_1014585.jpg row: 9, col: 2
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 0, col: 0
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 1, col: 3
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 1, col: 4
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 1, col: 11
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 1, col: 13
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 1, col: 19
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 1, col: 23
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 2, col: 10
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 2, col: 14
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 3, col: 22
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 4, col: 22
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 5, col: 1
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 6, col: 23
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 7, col: 15
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 8, col: 17
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 10, col: 16
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 10, col: 18
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 10, col: 22
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 11, col: 23
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 12, col: 9
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 13, col: 0
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 13, col: 3
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 13, col: 4
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 13, col: 23
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 14, col: 9
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 14, col: 18
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 14, col: 19
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 15, col: 1
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 15, col: 13
# ../cropped_second_batch_img/220215_140534_887736.jpg row: 15, col: 23
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 1, col: 20
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 4, col: 3
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 4, col: 5
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 5, col: 16
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 6, col: 20
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 7, col: 23
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 9, col: 20
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 10, col: 20
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 11, col: 16
# ../cropped_second_batch_img/220221_130612_891001.jpg row: 14, col: 20
# ../cropped_second_batch_img/220302_140244_896671.jpg row: 13, col: 1
# ../cropped_second_batch_img/220809_141346_992504.jpg row: 0, col: 4
# ../cropped_second_batch_img/220809_141346_992504.jpg row: 0, col: 6
# ../cropped_second_batch_img/220809_141346_992504.jpg row: 2, col: 12
# ../cropped_second_batch_img/220809_141346_992504.jpg row: 2, col: 16
# ../cropped_second_batch_img/220809_141346_992504.jpg row: 4, col: 0
# ../cropped_second_batch_img/220809_141346_992504.jpg row: 4, col: 20
# ../cropped_second_batch_img/220809_141346_992504.jpg row: 8, col: 8
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 0, col: 6
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 1, col: 12
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 1, col: 14
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 6, col: 0
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 7, col: 16
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 7, col: 18
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 10, col: 8
# ../cropped_second_batch_img/220413_140634_920284.jpg row: 10, col: 16
# ../cropped_second_batch_img/220915_130542_1018458.jpg row: 4, col: 20
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 0, col: 23
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 1, col: 23
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 6, col: 0
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 6, col: 2
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 6, col: 21
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 8, col: 1
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 10, col: 1
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 10, col: 23
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 12, col: 0
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 12, col: 4
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 14, col: 0
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 14, col: 2
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 14, col: 18
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 15, col: 3
# ../cropped_second_batch_img/220825_133551_1004039.jpg row: 15, col: 23
# ../cropped_second_batch_img/220504_151146_931369.jpg row: 0, col: 2
# ../cropped_second_batch_img/220504_151146_931369.jpg row: 0, col: 5
# ../cropped_second_batch_img/220504_151146_931369.jpg row: 0, col: 22
# ../cropped_second_batch_img/220504_151146_931369.jpg row: 4, col: 22
# ../cropped_second_batch_img/220504_151146_931369.jpg row: 14, col: 9
# ../cropped_second_batch_img/220223_172131_893156.jpg row: 0, col: 5
# ../cropped_second_batch_img/220223_172131_893156.jpg row: 1, col: 3
# ../cropped_second_batch_img/220223_172131_893156.jpg row: 1, col: 23
# ../cropped_second_batch_img/220223_172131_893156.jpg row: 15, col: 0
# ../cropped_second_batch_img/220223_172131_893156.jpg row: 15, col: 2
# ../cropped_second_batch_img/220927_123815_1026240.jpg row: 0, col: 4
# ../cropped_second_batch_img/220927_123815_1026240.jpg row: 15, col: 1
# ../cropped_second_batch_img/220224_134912_893654.jpg row: 0, col: 15
# ../cropped_second_batch_img/220224_134912_893654.jpg row: 0, col: 23
# ../cropped_second_batch_img/220224_134912_893654.jpg row: 2, col: 23
# ../cropped_second_batch_img/220224_134912_893654.jpg row: 10, col: 4
# ../cropped_second_batch_img/220224_134912_893654.jpg row: 12, col: 23
# ../cropped_second_batch_img/220411_131537_918954.jpg row: 15, col: 0
# ../cropped_second_batch_img/220428_114644_928397.jpg row: 0, col: 23
# ../cropped_second_batch_img/220829_134640_1005554.jpg row: 0, col: 0
# ../cropped_second_batch_img/220829_134640_1005554.jpg row: 0, col: 6
# ../cropped_second_batch_img/220829_134640_1005554.jpg row: 1, col: 22
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 1, col: 0
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 1, col: 4
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 1, col: 22
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 2, col: 2
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 3, col: 0
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 4, col: 0
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 10, col: 0
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 12, col: 20
# ../cropped_second_batch_img/220111_142653_865994.jpg row: 14, col: 23
# ../cropped_second_batch_img/220413_141959_920283.jpg row: 1, col: 21
# ../cropped_second_batch_img/220425_133133_926219.jpg row: 0, col: 0
# ../cropped_second_batch_img/220425_133133_926219.jpg row: 0, col: 23
# ../cropped_second_batch_img/220425_133133_926219.jpg row: 1, col: 13
# ../cropped_second_batch_img/220425_133133_926219.jpg row: 4, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 1
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 4
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 6
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 9
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 13
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 15
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 17
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 20
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 0, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 1, col: 0
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 1, col: 1
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 1, col: 4
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 1, col: 5
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 1, col: 6
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 1, col: 19
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 1, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 2, col: 1
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 2, col: 2
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 3, col: 5
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 3, col: 7
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 3, col: 13
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 3, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 6, col: 5
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 6, col: 17
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 6, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 7, col: 4
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 7, col: 16
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 8, col: 15
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 8, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 10, col: 3
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 10, col: 16
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 11, col: 0
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 12, col: 4
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 12, col: 5
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 12, col: 12
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 12, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 13, col: 0
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 13, col: 2
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 13, col: 4
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 13, col: 6
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 13, col: 16
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 13, col: 20
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 13, col: 22
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 14, col: 0
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 14, col: 3
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 14, col: 10
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 14, col: 21
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 15, col: 0
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 15, col: 2
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 15, col: 8
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 15, col: 16
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 15, col: 18
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 15, col: 20
# ../cropped_second_batch_img/220519_110919_940455.jpg row: 15, col: 22
# ../cropped_second_batch_img/220629_130024_964749.jpg row: 7, col: 6
# ../cropped_second_batch_img/220215_145350_887736.jpg row: 1, col: 13
# ../cropped_second_batch_img/220215_145350_887736.jpg row: 13, col: 1
# ../cropped_second_batch_img/220425_135315_926220.jpg row: 1, col: 2
# ../cropped_second_batch_img/220425_135315_926220.jpg row: 10, col: 2
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 0, col: 23
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 2, col: 21
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 6, col: 23
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 8, col: 17
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 10, col: 17
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 10, col: 23
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 12, col: 7
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 12, col: 9
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 12, col: 13
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 12, col: 15
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 12, col: 23
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 14, col: 7
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 14, col: 9
# ../cropped_second_batch_img/221019_115230_1043494.jpg row: 14, col: 23
# ../cropped_second_batch_img/220627_131000_962845.jpg row: 4, col: 22
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 0, col: 0
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 0, col: 1
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 0, col: 4
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 0, col: 17
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 1, col: 18
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 3, col: 3
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 3, col: 7
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 3, col: 22
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 4, col: 3
# ../cropped_second_batch_img/220118_134357_869671.jpg row: 13, col: 1
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 0, col: 19
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 0, col: 23
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 2, col: 22
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 6, col: 6
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 8, col: 0
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 8, col: 2
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 13, col: 22
# ../cropped_second_batch_img/220901_125859_1009352.jpg row: 15, col: 8
# ../cropped_second_batch_img/220908_122424_1014584.jpg row: 1, col: 23
# ../cropped_second_batch_img/220908_122424_1014584.jpg row: 15, col: 0
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 0, col: 3
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 0, col: 4
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 0, col: 8
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 0, col: 15
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 0, col: 22
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 1, col: 0
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 1, col: 17
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 1, col: 20
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 1, col: 21
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 5, col: 9
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 11, col: 22
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 13, col: 1
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 13, col: 13
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 13, col: 23
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 15, col: 0
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 15, col: 1
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 15, col: 14
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 15, col: 16
# ../cropped_second_batch_img/220330_141119_911814.jpg row: 15, col: 22
# ../cropped_second_batch_img/220815_122615_995736.jpg row: 2, col: 17
# ../cropped_second_batch_img/220815_122615_995736.jpg row: 8, col: 17
# ../cropped_second_batch_img/220815_122615_995736.jpg row: 12, col: 0
# ../cropped_second_batch_img/220815_122615_995736.jpg row: 13, col: 7
# ../cropped_second_batch_img/220815_122615_995736.jpg row: 15, col: 13
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 0, col: 18
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 3, col: 23
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 13, col: 1
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 13, col: 20
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 13, col: 22
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 14, col: 13
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 15, col: 2
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 15, col: 3
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 15, col: 6
# ../cropped_second_batch_img/220802_134644_987065.jpg row: 15, col: 8
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 0, col: 13
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 0, col: 23
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 1, col: 15
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 1, col: 23
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 6, col: 5
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 8, col: 21
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 12, col: 0
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 12, col: 22
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 14, col: 1
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 14, col: 18
# ../cropped_second_batch_img/221003_121946_1030366.jpg row: 14, col: 20
# ../cropped_second_batch_img/220823_140242_1000748.jpg row: 0, col: 23
# ../cropped_second_batch_img/220803_122749_988171.jpg row: 0, col: 13
# ../cropped_second_batch_img/220803_122749_988171.jpg row: 0, col: 21
# ../cropped_second_batch_img/220803_122749_988171.jpg row: 0, col: 23
# ../cropped_second_batch_img/220803_122749_988171.jpg row: 2, col: 22
# ../cropped_second_batch_img/220901_135833_1009355.jpg row: 0, col: 13
# ../cropped_second_batch_img/220901_135833_1009355.jpg row: 0, col: 17
# ../cropped_second_batch_img/220901_135833_1009355.jpg row: 0, col: 23
# ../cropped_second_batch_img/220901_135833_1009355.jpg row: 1, col: 23
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 0, col: 7
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 0, col: 13
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 0, col: 15
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 0, col: 16
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 0, col: 17
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 0, col: 19
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 0, col: 23
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 1, col: 20
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 1, col: 21
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 2, col: 1
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 2, col: 5
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 6, col: 21
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 6, col: 23
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 11, col: 11
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 15, col: 1
# ../cropped_second_batch_img/220906_113052_1012688.jpg row: 15, col: 6
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 0, col: 4
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 0, col: 17
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 3, col: 0
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 3, col: 16
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 3, col: 23
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 7, col: 1
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 11, col: 2
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 11, col: 11
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 13, col: 0
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 13, col: 2
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 13, col: 9
# ../cropped_second_batch_img/220517_132216_938699.jpg row: 15, col: 4
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 0, col: 4
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 0, col: 5
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 0, col: 8
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 0, col: 17
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 0, col: 22
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 1, col: 8
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 1, col: 10
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 1, col: 12
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 1, col: 23
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 2, col: 1
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 3, col: 0
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 3, col: 7
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 3, col: 13
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 3, col: 22
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 15, col: 0
# ../cropped_second_batch_img/220210_174351_885335.jpg row: 15, col: 22
# ../cropped_second_batch_img/220912_122918_1016143.jpg row: 0, col: 3
# ../cropped_second_batch_img/220912_122918_1016143.jpg row: 0, col: 13
# ../cropped_second_batch_img/220912_122918_1016143.jpg row: 12, col: 0
# ../cropped_second_batch_img/220912_122918_1016143.jpg row: 14, col: 22
# ../cropped_second_batch_img/220912_122918_1016143.jpg row: 15, col: 4
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 0, col: 16
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 1, col: 1
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 1, col: 21
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 1, col: 23
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 2, col: 9
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 4, col: 21
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 4, col: 23
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 6, col: 19
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 6, col: 21
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 7, col: 20
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 8, col: 0
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 8, col: 18
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 9, col: 9
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 9, col: 16
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 9, col: 18
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 10, col: 16
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 11, col: 12
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 11, col: 23
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 12, col: 12
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 13, col: 1
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 13, col: 12
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 13, col: 13
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 13, col: 17
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 13, col: 19
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 13, col: 20
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 13, col: 21
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 15, col: 4
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 15, col: 16
# ../cropped_second_batch_img/220214_130949_886939.jpg row: 15, col: 20
# ../cropped_second_batch_img/220829_135145_1005552.jpg row: 0, col: 7
# ../cropped_second_batch_img/220829_135145_1005552.jpg row: 2, col: 3
# ../cropped_second_batch_img/220829_135145_1005552.jpg row: 2, col: 22
# ../cropped_second_batch_img/220503_131304_930607.jpg row: 0, col: 20
# ../cropped_second_batch_img/220317_101904_905073.jpg row: 1, col: 20
# ../cropped_second_batch_img/220317_101904_905073.jpg row: 12, col: 23
# ../cropped_second_batch_img/220317_101904_905073.jpg row: 14, col: 19
# ../cropped_second_batch_img/220317_101904_905073.jpg row: 14, col: 21
# ../cropped_second_batch_img/220912_124515_1016141.jpg row: 10, col: 23
# ../cropped_second_batch_img/220912_124515_1016141.jpg row: 14, col: 5
# ../cropped_second_batch_img/220912_124515_1016141.jpg row: 15, col: 1
# ../cropped_second_batch_img/220517_143630_938701.jpg row: 0, col: 8
# ../cropped_second_batch_img/220517_143630_938701.jpg row: 13, col: 0
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 0, col: 8
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 0, col: 14
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 0, col: 21
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 0, col: 23
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 5, col: 21
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 7, col: 7
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 11, col: 4
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 12, col: 23
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 13, col: 1
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 13, col: 23
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 14, col: 3
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 15, col: 1
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 15, col: 2
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 15, col: 13
# ../cropped_second_batch_img/221020_143005_1044835.jpg row: 15, col: 20
# ../cropped_second_batch_img/220922_140333_1023602.jpg row: 0, col: 3
# ../cropped_second_batch_img/220922_140333_1023602.jpg row: 0, col: 19
# ../cropped_second_batch_img/220922_140333_1023602.jpg row: 0, col: 21
# ../cropped_second_batch_img/220922_140333_1023602.jpg row: 2, col: 13
# ../cropped_second_batch_img/220823_135338_1000747.jpg row: 0, col: 19
# ../cropped_second_batch_img/220831_120025_1008408.jpg row: 1, col: 22
# ../cropped_second_batch_img/220831_120025_1008408.jpg row: 2, col: 21
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 1, col: 0
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 1, col: 2
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 1, col: 11
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 1, col: 14
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 1, col: 21
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 2, col: 3
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 2, col: 5
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 2, col: 22
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 3, col: 1
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 3, col: 3
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 3, col: 5
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 3, col: 7
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 3, col: 15
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 3, col: 16
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 3, col: 23
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 5, col: 4
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 5, col: 7
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 7, col: 2
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 13, col: 12
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 13, col: 16
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 15, col: 0
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 15, col: 2
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 15, col: 4
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 15, col: 8
# ../cropped_second_batch_img/220216_135608_888495.jpg row: 15, col: 10
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 0, col: 17
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 0, col: 21
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 3, col: 1
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 3, col: 5
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 3, col: 7
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 3, col: 11
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 3, col: 23
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 5, col: 3
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 5, col: 7
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 5, col: 19
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 5, col: 23
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 7, col: 1
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 7, col: 13
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 7, col: 17
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 8, col: 8
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 8, col: 21
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 9, col: 4
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 9, col: 20
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 10, col: 15
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 11, col: 4
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 11, col: 9
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 11, col: 11
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 11, col: 13
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 12, col: 13
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 12, col: 18
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 12, col: 19
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 13, col: 1
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 13, col: 2
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 13, col: 3
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 13, col: 7
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 13, col: 12
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 13, col: 23
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 14, col: 7
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 14, col: 9
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 14, col: 22
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 1
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 3
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 5
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 7
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 9
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 14
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 17
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 19
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 21
# ../cropped_second_batch_img/220126_145744_875278.jpg row: 15, col: 23
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 0, col: 1
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 0, col: 7
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 0, col: 18
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 2, col: 22
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 3, col: 0
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 11, col: 11
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 12, col: 8
# ../cropped_second_batch_img/221004_123916_1031281.jpg row: 13, col: 18
# ../cropped_second_batch_img/220901_123421_1009350.jpg row: 4, col: 6
# ../cropped_second_batch_img/220901_123421_1009350.jpg row: 13, col: 12
# ../cropped_second_batch_img/220901_123421_1009350.jpg row: 15, col: 2
# ../cropped_second_batch_img/220926_130707_1025331.jpg row: 1, col: 1
# ../cropped_second_batch_img/220608_144204_951066.jpg row: 15, col: 3
# ../cropped_second_batch_img/220112_135157_866936.jpg row: 3, col: 23
# ../cropped_second_batch_img/220608_135436_951069.jpg row: 3, col: 23
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 0
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 1
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 2
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 4
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 5
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 8
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 13
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 19
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 20
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 21
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 0, col: 22
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 2, col: 1
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 2, col: 5
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 2, col: 9
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 2, col: 14
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 2, col: 22
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 4, col: 1
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 6, col: 1
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 6, col: 5
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 6, col: 7
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 6, col: 15
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 6, col: 17
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 6, col: 23
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 8, col: 0
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 8, col: 1
# ../cropped_second_batch_img/220509_122441_933654.jpg row: 8, col: 9
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 0, col: 6
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 0, col: 20
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 0, col: 21
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 1, col: 1
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 1, col: 21
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 1, col: 23
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 2, col: 3
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 2, col: 10
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 6, col: 13
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 11, col: 5
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 11, col: 12
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 11, col: 23
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 12, col: 23
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 13, col: 0
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 13, col: 1
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 14, col: 1
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 15, col: 0
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 15, col: 13
# ../cropped_second_batch_img/220427_132242_927663.jpg row: 15, col: 23
# ../cropped_second_batch_img/220505_123049_932182.jpg row: 0, col: 0
# ../cropped_second_batch_img/220505_123049_932182.jpg row: 0, col: 2
# ../cropped_second_batch_img/220505_123049_932182.jpg row: 0, col: 4
# ../cropped_second_batch_img/220505_123049_932182.jpg row: 0, col: 21
# ../cropped_second_batch_img/220505_123049_932182.jpg row: 1, col: 22
# ../cropped_second_batch_img/220505_123049_932182.jpg row: 4, col: 22
# ../cropped_second_batch_img/220505_123049_932182.jpg row: 6, col: 6
# ../cropped_second_batch_img/220628_135102_963614.jpg row: 1, col: 1
# ../cropped_second_batch_img/220628_135102_963614.jpg row: 3, col: 5
# ../cropped_second_batch_img/220628_135102_963614.jpg row: 11, col: 1
# ../cropped_second_batch_img/220628_135102_963614.jpg row: 13, col: 1
# ../cropped_second_batch_img/220628_135102_963614.jpg row: 13, col: 23
# ../cropped_second_batch_img/220628_135102_963614.jpg row: 15, col: 1
# ../cropped_second_batch_img/220628_135102_963614.jpg row: 15, col: 3
# ../cropped_second_batch_img/220728_135251_984258.jpg row: 1, col: 16
# ../cropped_second_batch_img/220728_135251_984258.jpg row: 12, col: 23
# ../cropped_second_batch_img/220728_135251_984258.jpg row: 14, col: 1
# ../cropped_second_batch_img/220728_135251_984258.jpg row: 14, col: 23
# ../cropped_second_batch_img/220517_134743_938699.jpg row: 9, col: 4
# ../cropped_second_batch_img/220517_134743_938699.jpg row: 11, col: 0
# ../cropped_second_batch_img/220517_134743_938699.jpg row: 11, col: 2
# ../cropped_second_batch_img/220517_134743_938699.jpg row: 13, col: 0
# ../cropped_second_batch_img/220517_134743_938699.jpg row: 15, col: 4
# ../cropped_second_batch_img/221004_132812_1031284.jpg row: 0, col: 23
# ../cropped_second_batch_img/221004_132812_1031284.jpg row: 10, col: 23
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 0, col: 0
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 0, col: 4
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 0, col: 6
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 0, col: 10
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 0, col: 22
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 2, col: 0
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 2, col: 3
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 2, col: 4
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 2, col: 13
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 5, col: 19
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 11, col: 2
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 13, col: 5
# ../cropped_second_batch_img/220829_122204_1005552.jpg row: 15, col: 0
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 0, col: 0
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 0, col: 1
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 0, col: 8
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 0, col: 13
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 0, col: 17
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 2, col: 9
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 2, col: 18
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 10, col: 4
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 12, col: 0
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 12, col: 20
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 13, col: 1
# ../cropped_second_batch_img/220126_154649_875277.jpg row: 14, col: 16
# ../cropped_second_batch_img/221024_124433_1046897.jpg row: 12, col: 18
# ../cropped_second_batch_img/220627_125041_962843.jpg row: 12, col: 22
# ../cropped_second_batch_img/220627_125041_962843.jpg row: 15, col: 2
# ../cropped_second_batch_img/220627_125041_962843.jpg row: 15, col: 22
# ../cropped_second_batch_img/221004_121734_1031279.jpg row: 3, col: 23
# ../cropped_second_batch_img/221004_121734_1031279.jpg row: 5, col: 19
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 0, col: 0
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 0, col: 3
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 0, col: 15
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 1, col: 12
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 1, col: 21
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 1, col: 23
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 2, col: 2
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 3, col: 18
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 4, col: 0
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 4, col: 8
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 4, col: 22
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 9, col: 11
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 11, col: 7
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 13, col: 1
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 13, col: 4
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 14, col: 1
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 14, col: 19
# ../cropped_second_batch_img/220426_130035_926918.jpg row: 15, col: 22
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 0, col: 1
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 0, col: 6
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 0, col: 23
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 1, col: 18
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 2, col: 4
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 2, col: 15
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 5, col: 21
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 7, col: 4
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 10, col: 2
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 10, col: 3
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 11, col: 0
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 11, col: 11
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 12, col: 17
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 14, col: 0
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 14, col: 5
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 14, col: 17
# ../cropped_second_batch_img/220922_132325_1023599.jpg row: 15, col: 3
# ../cropped_second_batch_img/220906_115405_1012688.jpg row: 0, col: 0
# ../cropped_second_batch_img/220906_115405_1012688.jpg row: 0, col: 19
# ../cropped_second_batch_img/220906_115405_1012688.jpg row: 0, col: 23
# ../cropped_second_batch_img/220512_121044_936234.jpg row: 1, col: 20
# ../cropped_second_batch_img/220512_121044_936234.jpg row: 2, col: 23
# ../cropped_second_batch_img/220512_121044_936234.jpg row: 5, col: 21
# ...
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 12, col: 6
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 0
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 1
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 2
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 4
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 6
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 8
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 12
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 16
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 18
# ../cropped_second_batch_img/220517_132554_938700.jpg row: 13, col: 23
# ../cropped_second_batch_img/220922_141428_1023599.jpg row: 0, col: 18
# ../cropped_second_batch_img/220922_141428_1023599.jpg row: 12, col: 23
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 0
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 3
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 5
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 7
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 13
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 14
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 15
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 19
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 0, col: 21
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 3
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 6
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 8
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 10
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 15
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 21
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 22
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 1, col: 23
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 2, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 2, col: 10
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 2, col: 21
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 2, col: 22
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 2, col: 23
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 3, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 3, col: 4
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 3, col: 18
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 3, col: 22
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 4, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 4, col: 2
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 4, col: 7
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 4, col: 22
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 4, col: 23
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 5, col: 0
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 4
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 5
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 6
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 7
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 8
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 9
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 18
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 20
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 6, col: 23
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 8, col: 0
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 8, col: 2
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 8, col: 5
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 8, col: 12
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 8, col: 20
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 9, col: 15
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 10, col: 0
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 10, col: 4
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 10, col: 16
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 11, col: 23
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 12, col: 4
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 12, col: 12
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 12, col: 13
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 12, col: 20
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 12, col: 23
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 13, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 13, col: 13
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 13, col: 17
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 14, col: 0
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 14, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 14, col: 2
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 14, col: 4
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 14, col: 5
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 14, col: 12
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 14, col: 22
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 15, col: 1
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 15, col: 13
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 15, col: 17
# ../cropped_second_batch_img/220504_143826_931373.jpg row: 15, col: 23
# ../cropped_second_batch_img/220405_124357_915570.jpg row: 9, col: 2
# ../cropped_second_batch_img/220601_134131_947483.jpg row: 11, col: 4
# ../cropped_second_batch_img/220601_134131_947483.jpg row: 11, col: 10
# ../cropped_second_batch_img/220601_134131_947483.jpg row: 13, col: 0
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 0, col: 19
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 0, col: 21
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 0, col: 23
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 1, col: 0
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 1, col: 20
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 1, col: 22
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 2, col: 1
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 2, col: 19
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 2, col: 21
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 3, col: 22
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 3, col: 23
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 5, col: 6
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 7, col: 16
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 7, col: 22
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 9, col: 11
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 13, col: 2
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 13, col: 4
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 15, col: 0
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 15, col: 16
# ../cropped_second_batch_img/220427_125946_927661.jpg row: 15, col: 18
# ../cropped_second_batch_img/220802_142456_987061.jpg row: 0, col: 4
# ../cropped_second_batch_img/220802_142456_987061.jpg row: 0, col: 7
# ../cropped_second_batch_img/220802_142456_987061.jpg row: 14, col: 2
# ../cropped_second_batch_img/220802_142456_987061.jpg row: 14, col: 5
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 0, col: 0
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 0, col: 1
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 0, col: 8
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 0, col: 10
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 0, col: 15
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 0, col: 16
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 0, col: 17
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 1, col: 0
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 1, col: 8
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 2, col: 1
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 2, col: 23
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 3, col: 4
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 3, col: 10
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 4, col: 19
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 4, col: 21
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 5, col: 2
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 6, col: 0
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 6, col: 1
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 6, col: 5
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 6, col: 16
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 6, col: 21
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 6, col: 23
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 8, col: 0
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 8, col: 11
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 8, col: 15
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 9, col: 4
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 9, col: 12
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 10, col: 5
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 10, col: 13
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 10, col: 16
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 12, col: 0
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 12, col: 7
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 14, col: 3
# ../cropped_second_batch_img/220502_123654_929776.jpg row: 15, col: 0
# ../cropped_second_batch_img/220802_150703_987066.jpg row: 0, col: 23
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 1
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 4
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 5
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 6
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 7
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 13
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 17
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 21
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 0, col: 23
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 1, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 1, col: 2
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 1, col: 8
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 1, col: 22
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 2, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 2, col: 3
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 3, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 3, col: 6
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 3, col: 14
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 4, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 4, col: 14
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 4, col: 22
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 5, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 5, col: 10
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 6, col: 14
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 6, col: 20
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 7, col: 4
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 8, col: 21
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 9, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 9, col: 12
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 1
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 2
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 4
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 10
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 15
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 21
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 10, col: 23
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 11, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 11, col: 16
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 11, col: 18
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 12, col: 4
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 12, col: 7
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 12, col: 11
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 13, col: 21
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 13, col: 23
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 14, col: 0
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 14, col: 1
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 14, col: 5
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 14, col: 11
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 14, col: 14
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 14, col: 18
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 15, col: 3
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 15, col: 5
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 15, col: 7
# ../cropped_second_batch_img/220505_120807_932182.jpg row: 15, col: 9
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 0, col: 0
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 0, col: 1
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 0, col: 3
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 0, col: 6
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 0, col: 15
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 0, col: 19
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 0, col: 23
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 1, col: 2
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 1, col: 8
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 1, col: 20
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 2, col: 10
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 7, col: 4
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 7, col: 6
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 9, col: 8
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 11, col: 0
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 13, col: 4
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 13, col: 6
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 13, col: 8
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 13, col: 14
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 15, col: 0
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 15, col: 2
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 15, col: 4
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 15, col: 8
# ../cropped_second_batch_img/221010_130832_1036687.jpg row: 15, col: 20
# 0.9704937279184838
# (array([   2.,    0.,    2.,    0.,    8.,    4.,   16.,   21.,   52.,
#         1106.]),
#  array([0.16710875, 0.25039788, 0.333687  , 0.41697613, 0.50026525,
#         0.58355438, 0.6668435 , 0.75013263, 0.83342175, 0.91671088,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
print(true_false_neg_counter, failed_bc_dispense, failed_not_dc_dispense, ngs_success_counter, ngs_failed_counter, ngs_nan)
# Out:
# 5800 0.04010115606936416 0.9598988439306358 220793 74736 161018

# %%
ngs_nan/(ngs_success_counter + ngs_failed_counter + ngs_nan)
# Out:
# 0.35268657991400665

# %%
"""
../cropped_second_batch_img/220223_173011_893157.jpg row: 1, col: 0
../cropped_second_batch_img/220223_173011_893157.jpg row: 1, col: 22
../cropped_second_batch_img/220223_173011_893157.jpg row: 2, col: 10
../cropped_second_batch_img/220223_173011_893157.jpg row: 4, col: 14
../cropped_second_batch_img/220223_173011_893157.jpg row: 6, col: 23
../cropped_second_batch_img/220223_173011_893157.jpg row: 11, col: 0
../cropped_second_batch_img/220223_173011_893157.jpg row: 14, col: 2
../cropped_second_batch_img/220223_173011_893157.jpg row: 15, col: 19
"""
filename = '../cropped_second_batch_img/220223_173011_893157.jpg'
img = Image.open(filename)
plt.figure(0)
plt.imshow(np.array(img))
plt.figure(1)
plt.imshow(load_and_preprocess_img(filename=filename, gaussian_kernel_size=(3,3), thresh=cv2.THRESH_BINARY, adapt=cv2.ADAPTIVE_THRESH_GAUSSIAN_C, adp_th_block_size=5, adp_th_const=4, gaussian_sigma=1.0))

# %%
trueFN = pd.read_csv('trueFN.txt', sep='\s', header=None)
imgs = np.unique(trueFN.iloc[:,0].to_numpy())
for idx, file in enumerate(imgs):
    # img = Image.open(file)
    img =cv2.imread(file)
    plt.figure(idx)
    plt.imshow(np.array(img))
# Out:
# /var/folders/7q/dz1j3pf94y72r9p92m3zyss40000gn/T/ipykernel_20275/1685585683.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   trueFN = pd.read_csv('trueFN.txt', sep='\s', header=None)
# /var/folders/7q/dz1j3pf94y72r9p92m3zyss40000gn/T/ipykernel_20275/1685585683.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(idx)
